# %% [markdown]
# Below github link gives the upto date information above the noval caronavirus.
# Data: https://github.com/CSSEGISandData/COVID-19
# Feel free to provide me with feedbacks.
# Last update: 4/1/2020 8:16 PM

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import matplotlib.colors as mcolors
import pandas as pd 
import random
import math
import time
from sklearn.linear_model import LinearRegression, BayesianRidge
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, mean_absolute_error
import datetime
import operator 
plt.style.use('fivethirtyeight')
# %matplotlib inline 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Import the data

# %%
confirmed_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
deaths_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')
recoveries_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv')
latest_data = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-01-2020.csv')

# %%
latest_data.head()
# Out:
#       FIPS     Admin2  Province_State Country_Region          Last_Update  \
# 0  45001.0  Abbeville  South Carolina             US  2020-04-01 21:58:49
# 1  22001.0     Acadia       Louisiana             US  2020-04-01 21:58:49
# 2  51001.0   Accomack        Virginia             US  2020-04-01 21:58:49
# 3  16001.0        Ada           Idaho             US  2020-04-01 21:58:49
# 4  19001.0      Adair            Iowa             US  2020-04-01 21:58:49
#
#          Lat       Long_  Confirmed  Deaths  Recovered  Active  \
# 0  34.223334  -82.461707          4       0          0       0
# 1  30.295065  -92.414197         47       1          0       0
# 2  37.767072  -75.632346          7       0          0       0
# 3  43.452658 -116.241552        195       3          0       0
# 4  41.330756  -94.471059          1       0          0       0
#
#                     Combined_Key
# 0  Abbeville, South Carolina, US
# 1          Acadia, Louisiana, US
# 2         Accomack, Virginia, US
# 3                 Ada, Idaho, US
# 4                Adair, Iowa, US

# %%
confirmed_df.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20   ...    3/23/20  3/24/20  3/25/20  3/26/20  \
# 0        0        0        0   ...         40       74       84       94
# 1        0        0        0   ...        104      123      146      174
# 2        0        0        0   ...        230      264      302      367
# 3        0        0        0   ...        133      164      188      224
# 4        0        0        0   ...          3        3        3        4
#
#    3/27/20  3/28/20  3/29/20  3/30/20  3/31/20  4/1/20
# 0      110      110      120      170      174     237
# 1      186      197      212      223      243     259
# 2      409      454      511      584      716     847
# 3      267      308      334      370      376     390
# 4        4        5        7        7        7       8
#
# [5 rows x 75 columns]

# %%
#Getting the list of all the columns in the dataset
cols = confirmed_df.keys()

# %% [markdown]
# Get all the dates for the outbreak

# %%
confirmed = confirmed_df.loc[:, cols[4]:cols[-1]]
deaths = deaths_df.loc[:, cols[4]:cols[-1]]
recoveries = recoveries_df.loc[:, cols[4]:cols[-1]]

# %%
#get all the dates in to dates
dates = confirmed.keys()

world_cases = []
total_deaths = [] 
mortality_rate = []
recovery_rate = [] 
total_recovered = [] 
total_active = [] 
china_cases = [] 
italy_cases = []
us_cases = [] 
spain_cases = [] 
france_cases = [] 

for i in dates:
    confirmed_sum = confirmed[i].sum()
    death_sum = deaths[i].sum()
    recovered_sum = recoveries[i].sum()
    
    # confirmed, deaths, recovered, and active
    world_cases.append(confirmed_sum)
    total_deaths.append(death_sum)
    total_recovered.append(recovered_sum)
    total_active.append(confirmed_sum-death_sum-recovered_sum)
    
    # calculate rates
    mortality_rate.append(death_sum/confirmed_sum)
    recovery_rate.append(recovered_sum/confirmed_sum)

    # case studies 
    china_cases.append(confirmed_df[confirmed_df['Country/Region']=='China'][i].sum())
    italy_cases.append(confirmed_df[confirmed_df['Country/Region']=='Italy'][i].sum())
    us_cases.append(confirmed_df[confirmed_df['Country/Region']=='US'][i].sum())
    spain_cases.append(confirmed_df[confirmed_df['Country/Region']=='Spain'][i].sum())
    france_cases.append(confirmed_df[confirmed_df['Country/Region']=='France'][i].sum())

# %% [markdown]
# Getting daily increases

# %%
def daily_increase(data):
    d = [] 
    for i in range(len(data)):
        if i == 0:
            d.append(data[0])
        else:
            d.append(data[i]-data[i-1])
    return d 

world_daily_increase = daily_increase(world_cases)
china_daily_increase = daily_increase(china_cases)
italy_daily_increase = daily_increase(italy_cases)
us_daily_increase = daily_increase(us_cases)
spain_daily_increase = daily_increase(spain_cases)
france_daily_increase = daily_increase(france_cases)

# %%
days_since_1_22 = np.array([i for i in range(len(dates))]).reshape(-1, 1)
world_cases = np.array(world_cases).reshape(-1, 1)
total_deaths = np.array(total_deaths).reshape(-1, 1)
total_recovered = np.array(total_recovered).reshape(-1, 1)

# %% [markdown]
# Future forcasting

# %%
#ading next ten days to the list of days
days_in_future = 10
future_forcast = np.array([i for i in range(len(dates)+days_in_future)]).reshape(-1, 1)
adjusted_dates = future_forcast[:-10]

# %% [markdown]
# Convert integer into datetime for better visualization

# %%
start = '1/22/2020'
start_date = datetime.datetime.strptime(start, '%m/%d/%Y')
future_forcast_dates = []
for i in range(len(future_forcast)):
    future_forcast_dates.append((start_date + datetime.timedelta(days=i)).strftime('%m/%d/%Y'))

# %%
#Here weare splitting the train and test data
X_train_confirmed, X_test_confirmed, y_train_confirmed, y_test_confirmed = train_test_split(days_since_1_22, world_cases, test_size=0.05, shuffle=False)

# %% [markdown]
# Model for predicting confirmed cases. I am using support vector machine, and linear polynomial regression in this example.

# %%
# svm_search.best_params_

# %%
# svm_confirmed = svm_search.best_estimator_
svm_confirmed = SVR(shrinking=True, kernel='poly',gamma=0.01, epsilon=1,degree=8, C=0.1)
svm_confirmed.fit(X_train_confirmed, y_train_confirmed)
#predicting next ten days 
svm_pred = svm_confirmed.predict(future_forcast)

# %%
# check against testing data
svm_test_pred = svm_confirmed.predict(X_test_confirmed)
plt.plot(y_test_confirmed)
plt.plot(svm_test_pred)
plt.legend(['Test Data', 'SVM Predictions'])
print('MAE:', mean_absolute_error(svm_test_pred, y_test_confirmed))
print('MSE:',mean_squared_error(svm_test_pred, y_test_confirmed))
# Out:
# MAE: 87332.48508902802
# MSE: 8518663192.905856

# %%
# transform our data for polynomial regression
poly = PolynomialFeatures(degree=6)
poly_X_train_confirmed = poly.fit_transform(X_train_confirmed)
poly_X_test_confirmed = poly.fit_transform(X_test_confirmed)
poly_future_forcast = poly.fit_transform(future_forcast)

# %%
# polynomial regression
linear_model = LinearRegression(normalize=True, fit_intercept=False)
linear_model.fit(poly_X_train_confirmed, y_train_confirmed)
test_linear_pred = linear_model.predict(poly_X_test_confirmed)
linear_pred = linear_model.predict(poly_future_forcast)
print('MAE:', mean_absolute_error(test_linear_pred, y_test_confirmed))
print('MSE:',mean_squared_error(test_linear_pred, y_test_confirmed))
# Out:
# MAE: 55777.79199581011
# MSE: 3898902698.90318

# %%
plt.plot(y_test_confirmed)
plt.plot(test_linear_pred)
plt.legend(['Test Data', 'Polynomial Regression Predictions'])

# %% [markdown]
#  Graphing the number of confirmed cases, active cases, deaths, recoveries, mortality rate, and recovery rate

# %%
adjusted_dates = adjusted_dates.reshape(1, -1)[0]
plt.figure(figsize=(16, 9))
plt.plot(adjusted_dates, world_cases)
plt.title('# of Coronavirus Cases Over Time', size=30)
plt.xlabel('Days Since 1/22/2020', size=30)
plt.ylabel('# of Cases', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %%
plt.figure(figsize=(16, 9))
plt.plot(adjusted_dates, china_cases)
plt.plot(adjusted_dates, italy_cases)
plt.plot(adjusted_dates, us_cases)
plt.plot(adjusted_dates, spain_cases)
plt.plot(adjusted_dates, france_cases)
plt.title('# of Coronavirus Cases', size=30)
plt.xlabel('Days Since 1/22/2020', size=30)
plt.ylabel('# of Cases', size=30)
plt.legend(['China', 'Italy', 'US', 'Spain', 'France'], prop={'size': 20})
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %%
plt.figure(figsize=(16, 9))
plt.plot(adjusted_dates, world_cases)
plt.plot(future_forcast, svm_pred, linestyle='dashed', color='purple')
plt.title('# of Coronavirus Cases Over Time', size=30)
plt.xlabel('Days Since 1/22/2020', size=30)
plt.ylabel('# of Cases', size=30)
plt.legend(['Confirmed Cases', 'SVM predictions'], prop={'size': 20})
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %%
plt.figure(figsize=(16, 9))
plt.plot(adjusted_dates, world_cases)
plt.plot(future_forcast, linear_pred, linestyle='dashed', color='orange')
plt.title('# of Coronavirus Cases Over Time', size=30)
plt.xlabel('Days Since 1/22/2020', size=30)
plt.ylabel('# of Cases', size=30)
plt.legend(['Confirmed Cases', 'Polynomial Regression Predictions'], prop={'size': 20})
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %% [markdown]
# Predicting Feature Increase in the cases

# %%
# Future predictions using SVM 
print('SVM future predictions:')
set(zip(future_forcast_dates[-10:], np.round(svm_pred[-10:])))
# Out:
# SVM future predictions:
# {('04/02/2020', 1181747.0),
#  ('04/03/2020', 1313525.0),
#  ('04/04/2020', 1458758.0),
#  ('04/05/2020', 1618606.0),
#  ('04/06/2020', 1794311.0),
#  ('04/07/2020', 1987204.0),
#  ('04/08/2020', 2198705.0),
#  ('04/09/2020', 2430334.0),
#  ('04/10/2020', 2683710.0),
#  ('04/11/2020', 2960559.0)}

# %%
# Future predictions using Polynomial Regression 
linear_pred = linear_pred.reshape(1,-1)[0]
print('Polynomial regression future predictions:')
set(zip(future_forcast_dates[-10:], np.round(linear_pred[-10:])))
# Out:
# Polynomial regression future predictions:
# {('04/02/2020', 1145201.0),
#  ('04/03/2020', 1273906.0),
#  ('04/04/2020', 1415243.0),
#  ('04/05/2020', 1570170.0),
#  ('04/06/2020', 1739700.0),
#  ('04/07/2020', 1924899.0),
#  ('04/08/2020', 2126891.0),
#  ('04/09/2020', 2346859.0),
#  ('04/10/2020', 2586049.0),
#  ('04/11/2020', 2845767.0)}

# %% [markdown]
# Getting information about countries/regions that have confirmed coronavirus cases

# %%
unique_countries =  list(latest_data['Country_Region'].unique())

# %%
country_confirmed_cases = []
country_death_cases = [] 
country_recovery_cases = []
country_mortality_rate = [] 

no_cases = []
for i in unique_countries:
    cases = latest_data[latest_data['Country_Region']==i]['Confirmed'].sum()
    if cases > 0:
        country_confirmed_cases.append(cases)
    else:
        no_cases.append(i)
        
for i in no_cases:
    unique_countries.remove(i)
    
# sort countries by the number of confirmed cases

unique_countries = [k for k, v in sorted(zip(unique_countries, country_confirmed_cases), key=operator.itemgetter(1), reverse=True)]
for i in range(len(unique_countries)):
    country_confirmed_cases[i] = latest_data[latest_data['Country_Region']==unique_countries[i]]['Confirmed'].sum()
    country_death_cases.append(latest_data[latest_data['Country_Region']==unique_countries[i]]['Deaths'].sum())
    country_recovery_cases.append(latest_data[latest_data['Country_Region']==unique_countries[i]]['Recovered'].sum())
    country_mortality_rate.append(country_death_cases[i]/country_confirmed_cases[i])

# %%
country_df = pd.DataFrame({'Country Name': unique_countries, 'Number of Confirmed Cases': country_confirmed_cases,
                          'Number of Deaths': country_death_cases, 'Number of Recoveries' : country_recovery_cases,
                          'Mortality Rate': country_mortality_rate})
# number of cases per country/region

country_df.style.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
#     #T_27a965c0_74ee_11ea_979d_34415d579dd2row0_col1 {
#             background-color:  #08306b;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row0_col2 {
#             background-color:  #a3cce3;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row0_col3 {
#             background-color:  #e1edf8;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row0_col4 {
#             background-color:  #e8f1fa;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row1_col1 {
#             background-color:  #65aad4;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row1_col2 {
#             background-color:  #08306b;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row1_col3 {
#             background-color:  #ccdff1;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row1_col4 {
#             background-color:  #8dc1dd;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row2_col1 {
#             background-color:  #71b1d7;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row2_col2 {
#             background-color:  #2b7bba;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row2_col3 {
#             background-color:  #b8d5ea;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row2_col4 {
#             background-color:  #b2d2e8;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row3_col1 {
#             background-color:  #9ac8e0;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row3_col2 {
#             background-color:  #c6dbef;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row3_col3 {
#             background-color:  #08306b;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row3_col4 {
#             background-color:  #dbe9f6;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row4_col1 {
#             background-color:  #a1cbe2;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row4_col2 {
#             background-color:  #eaf2fb;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row4_col3 {
#             background-color:  #c7dcef;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row4_col4 {
#             background-color:  #eff6fc;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row5_col1 {
#             background-color:  #bfd8ed;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row5_col2 {
#             background-color:  #b4d3e9;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row5_col3 {
#             background-color:  #dae8f6;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row5_col4 {
#             background-color:  #c7dcef;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row6_col1 {
#             background-color:  #cbdef1;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row6_col2 {
#             background-color:  #caddf0;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row6_col3 {
#             background-color:  #d0e1f2;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row6_col4 {
#             background-color:  #cbdef1;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row7_col1 {
#             background-color:  #dce9f6;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row7_col2 {
#             background-color:  #d4e4f4;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row7_col3 {
#             background-color:  #f7fbff;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row7_col4 {
#             background-color:  #bed8ec;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row8_col1 {
#             background-color:  #e7f0fa;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row8_col2 {
#             background-color:  #f0f6fd;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row8_col3 {
#             background-color:  #f0f6fd;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row8_col4 {
#             background-color:  #e4eff9;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row9_col1 {
#             background-color:  #e9f2fa;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row9_col2 {
#             background-color:  #f3f8fe;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row9_col3 {
#             background-color:  #f6faff;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row9_col4 {
#             background-color:  #ebf3fb;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row10_col1 {
#             background-color:  #eaf3fb;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row10_col2 {
#             background-color:  #eaf3fb;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row10_col3 {
#             background-color:  #f2f7fd;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row10_col4 {
#             background-color:  #cee0f2;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row11_col1 {
#             background-color:  #eaf3fb;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row11_col2 {
#             background-color:  #e6f0f9;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row11_col3 {
#             background-color:  #f7fbff;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row11_col4 {
#             background-color:  #b7d4ea;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row12_col1 {
#             background-color:  #eef5fc;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row12_col2 {
#             background-color:  #f5fafe;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row12_col3 {
#             background-color:  #f4f9fe;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row12_col4 {
#             background-color:  #eef5fc;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row13_col1 {
#             background-color:  #eef5fc;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row13_col2 {
#             background-color:  #f5f9fe;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row13_col3 {
#             background-color:  #e9f2fa;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row13_col4 {
#             background-color:  #ecf4fb;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row14_col1 {
#             background-color:  #eef5fc;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row14_col2 {
#             background-color:  #f5fafe;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row14_col3 {
#             background-color:  #f4f9fe;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row14_col4 {
#             background-color:  #eff6fc;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row15_col1 {
#             background-color:  #f0f6fd;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row15_col2 {
#             background-color:  #f5f9fe;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row15_col3 {
#             background-color:  #f7fbff;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row15_col4 {
#             background-color:  #e7f1fa;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row16_col1 {
#             background-color:  #f1f7fd;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row16_col2 {
#             background-color:  #f4f9fe;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row16_col3 {
#             background-color:  #f7fbff;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row16_col4 {
#             background-color:  #dfebf7;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row17_col1 {
#             background-color:  #f2f7fd;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row17_col2 {
#             background-color:  #f7fbff;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row17_col3 {
#             background-color:  #f7fbff;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row17_col4 {
#             background-color:  #f5f9fe;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row18_col1 {
#             background-color:  #f3f8fe;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row18_col2 {
#             background-color:  #f4f9fe;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row18_col3 {
#             background-color:  #f7fbff;
#         }    #T_27a965c0_74ee_11ea_979d_34415d579dd2row18_col4 {
#             background-color:  #d6e5f4;
#         }    #T_27a965c0_74ee_11ea_979d_344

# %% [markdown]
# Getting the latest information about provinces/states that have confirmed coronavirus cases

# %%
unique_provinces =  list(latest_data['Province_State'].unique())

# %%
province_confirmed_cases = []
province_country = [] 
province_death_cases = [] 
province_recovery_cases = []
province_mortality_rate = [] 

no_cases = [] 
for i in unique_provinces:
    cases = latest_data[latest_data['Province_State']==i]['Confirmed'].sum()
    if cases > 0:
        province_confirmed_cases.append(cases)
    else:
        no_cases.append(i)
 
# remove areas with no confirmed cases
for i in no_cases:
    unique_provinces.remove(i)
    
unique_provinces = [k for k, v in sorted(zip(unique_provinces, province_confirmed_cases), key=operator.itemgetter(1), reverse=True)]
for i in range(len(unique_provinces)):
    province_confirmed_cases[i] = latest_data[latest_data['Province_State']==unique_provinces[i]]['Confirmed'].sum()
    province_country.append(latest_data[latest_data['Province_State']==unique_provinces[i]]['Country_Region'].unique()[0])
    province_death_cases.append(latest_data[latest_data['Province_State']==unique_provinces[i]]['Deaths'].sum())
    province_recovery_cases.append(latest_data[latest_data['Province_State']==unique_provinces[i]]['Recovered'].sum())
    province_mortality_rate.append(province_death_cases[i]/province_confirmed_cases[i])

# %%
# number of cases per province/state/city
province_df = pd.DataFrame({'Province/State Name': unique_provinces, 'Country': province_country, 'Number of Confirmed Cases': province_confirmed_cases,
                          'Number of Deaths': province_death_cases, 'Number of Recoveries' : province_recovery_cases,
                          'Mortality Rate': province_mortality_rate})
# number of cases per country/region

province_df.style.background_gradient(cmap='Greens')
# Out:
# <style  type="text/css" >
#     #T_31a6ab54_74ee_11ea_b340_34415d579dd2row0_col2 {
#             background-color:  #00441b;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row0_col3 {
#             background-color:  #48ae60;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row0_col4 {
#             background-color:  #f7fcf5;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row0_col5 {
#             background-color:  #e2f4dd;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row1_col2 {
#             background-color:  #137d39;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row1_col3 {
#             background-color:  #00441b;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row1_col4 {
#             background-color:  #00441b;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row1_col5 {
#             background-color:  #bde5b6;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row2_col2 {
#             background-color:  #c3e7bc;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row2_col3 {
#             background-color:  #e7f6e3;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row2_col4 {
#             background-color:  #f7fcf5;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row2_col5 {
#             background-color:  #e9f7e5;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row3_col2 {
#             background-color:  #e7f6e3;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row3_col3 {
#             background-color:  #eff9eb;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row3_col4 {
#             background-color:  #f7fcf5;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row3_col5 {
#             background-color:  #e5f5e0;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row4_col2 {
#             background-color:  #e7f6e3;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row4_col3 {
#             background-color:  #e8f6e4;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row4_col4 {
#             background-color:  #f7fcf5;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row4_col5 {
#             background-color:  #cfecc9;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row5_col2 {
#             background-color:  #eaf7e6;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row5_col3 {
#             background-color:  #f2faef;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row5_col4 {
#             background-color:  #f7fcf5;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row5_col5 {
#             background-color:  #e9f7e5;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row6_col2 {
#             background-color:  #ebf7e7;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row6_col3 {
#             background-color:  #f1faee;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row6_col4 {
#             background-color:  #f7fcf5;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row6_col5 {
#             background-color:  #e5f5e1;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row7_col2 {
#             background-color:  #ebf7e7;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row7_col3 {
#             background-color:  #f4fbf1;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row7_col4 {
#             background-color:  #f7fcf5;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row7_col5 {
#             background-color:  #ecf8e8;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row8_col2 {
#             background-color:  #ecf8e8;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row8_col3 {
#             background-color:  #ebf7e7;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row8_col4 {
#             background-color:  #f7fcf5;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row8_col5 {
#             background-color:  #c6e8bf;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row9_col2 {
#             background-color:  #edf8e9;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row9_col3 {
#             background-color:  #f4fbf2;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row9_col4 {
#             background-color:  #f7fcf5;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row9_col5 {
#             background-color:  #edf8e9;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row10_col2 {
#             background-color:  #edf8ea;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row10_col3 {
#             background-color:  #edf8e9;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row10_col4 {
#             background-color:  #f7fcf5;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row10_col5 {
#             background-color:  #c7e9c0;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row11_col2 {
#             background-color:  #eff9ec;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row11_col3 {
#             background-color:  #f1faee;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row11_col4 {
#             background-color:  #f7fcf5;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row11_col5 {
#             background-color:  #d8f0d2;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row12_col2 {
#             background-color:  #eff9ec;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row12_col3 {
#             background-color:  #f6fcf4;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row12_col4 {
#             background-color:  #f7fcf5;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row12_col5 {
#             background-color:  #f1faee;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row13_col2 {
#             background-color:  #f0f9ec;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row13_col3 {
#             background-color:  #f4fbf2;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row13_col4 {
#             background-color:  #f7fcf5;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row13_col5 {
#             background-color:  #eaf7e6;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row14_col2 {
#             background-color:  #f1faee;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row14_col3 {
#             background-color:  #f4fbf1;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row14_col4 {
#             background-color:  #f7fcf5;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row14_col5 {
#             background-color:  #e1f3dc;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row15_col2 {
#             background-color:  #f2faef;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row15_col3 {
#             background-color:  #f4fbf2;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row15_col4 {
#             background-color:  #f7fcf5;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row15_col5 {
#             background-color:  #e2f4dd;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row16_col2 {
#             background-color:  #f2faf0;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row16_col3 {
#             background-color:  #f6fcf4;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row16_col4 {
#             background-color:  #f7fcf5;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row16_col5 {
#             background-color:  #f0f9ed;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row17_col2 {
#             background-color:  #f3faf0;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row17_col3 {
#             background-color:  #f4fbf2;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row17_col4 {
#             background-color:  #f7fcf5;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row17_col5 {
#             background-color:  #dff3da;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row18_col2 {
#             background-color:  #f3faf0;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row18_col3 {
#             background-color:  #f4fbf2;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row18_col4 {
#             background-color:  #f7fcf5;
#         }    #T_31a6ab54_74ee_11ea_b340_34415d579dd2row18_col5 {
#             background-color:  #def2d9;
#         }    #T_31a6ab54_74ee_11ea_b340_344
